# %% [markdown]
# # 06 — Interprétation et erreurs (Membre 7)

# %%
import pandas as pd
from pathlib import Path
import sys
import warnings
warnings.filterwarnings("ignore")

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.utils import (
    RANDOM_STATE, TARGET_COL, TIME_COL, RAW_DIR, PROCESSED_DIR, FIGURES_DIR,
    load_raw_data, set_seed, ensure_dirs, save_figure, PROJECT_ROOT,
)
set_seed(RANDOM_STATE)
ensure_dirs()
print("ROOT =", ROOT)
print("RANDOM_STATE =", RANDOM_STATE)

import json
from IPython.display import Image, display
r=json.loads((PROCESSED_DIR/"results.json").read_text())
print("Modèle final:", r["best_model"], "seuil", r["threshold"], "F1", r["best_metrics"]["f1"])
print("\nFaux positifs (maintenue mais prédite annulée):")
display(pd.DataFrame(r["false_positives"]))
print("\nFaux négatifs (annulée non détectée):")
display(pd.DataFrame(r["false_negatives"]))
for fig in ["09_f1_vs_seuil.png","11_confusion_seuil_opt.png","12_permutation_importance.png"]:
    p=FIGURES_DIR/fig
    if p.exists():
        display(Image(filename=str(p)))
import pandas as pd
