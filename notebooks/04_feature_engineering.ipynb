# %% [markdown]
# # 04 — Feature engineering (Membre 4)
#
# Ablation des groupes de features + checklist anti-fuite.

# %%
from pathlib import Path
import sys
import warnings
warnings.filterwarnings("ignore")

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.utils import (
    RANDOM_STATE, TARGET_COL, TIME_COL, RAW_DIR, PROCESSED_DIR, FIGURES_DIR,
    load_raw_data, set_seed, ensure_dirs, save_figure, PROJECT_ROOT,
)
set_seed(RANDOM_STATE)
ensure_dirs()
print("ROOT =", ROOT)
print("RANDOM_STATE =", RANDOM_STATE)

import pandas as pd
from src.features import engineer_features, leakage_checklist, FEATURE_GROUPS
print(pd.DataFrame(leakage_checklist()))
abl = pd.read_csv(PROCESSED_DIR/"ablation_features.csv") if (PROCESSED_DIR/"ablation_features.csv").exists() else None
if abl is not None:
    display(abl)
else:
    print("Lancer scripts/run_pipeline.py pour générer l'ablation.")
print("Groupes:", {k:len(v) for k,v in FEATURE_GROUPS.items()})
